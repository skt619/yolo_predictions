# %%
import os
from glob import glob # extract path of each file
import pandas as pd # data preprocessing
from functools import reduce

# %%
dfAnno_test = pd.read_csv('/kaggle/input/data-data/test/annotations.csv')
dfAnno_train = pd.read_csv('/kaggle/input/data-data/train/annotations.csv')
dfAnnoBall_test = dfAnno_test[dfAnno_test["class"] == "player"]
dfAnnoBall_train = dfAnno_train[dfAnno_train["class"] == "player"]

# %%
dfAnno_test['class'].value_counts()
# Out:
# player      173
# football     13
# referee       8
# Name: class, dtype: int64

# %%
dfAnno_train['class'].value_counts()
# Out:
# player      1234
# football     100
# referee       68
# Name: class, dtype: int64

# %%
imagesToTrain=dfAnnoBall_train["filename"]
imagesToTest=dfAnnoBall_test["filename"]

# %%
imagesTrain = dfAnnoBall_train['filename'].unique()
len(imagesTrain)
# Out:
# 114

# %%
imagesTest = dfAnnoBall_test['filename'].unique()
len(imagesTest)
# Out:
# 16

# %%
imagesTrain_df = pd.DataFrame(imagesTrain,columns=['filename'])
img_train = tuple(imagesTrain_df['filename'])

# %%
imagesTest_df = pd.DataFrame(imagesTest,columns=['filename'])
img_test = tuple(imagesTest_df['filename'])

# %%
len(img_train), len(img_test)
# Out:
# (114, 16)

# %%
train_df = dfAnnoBall_train.query(f'filename in {img_train}')
test_df = dfAnnoBall_test.query(f'filename in {img_test}')

# %%
# center x, center y
train_df['center_x'] = ((train_df['xmax']+train_df['xmin'])/2)/train_df['width']
train_df['center_y'] = ((train_df['ymax']+train_df['ymin'])/2)/train_df['height']
# w
train_df['w'] = (train_df['xmax']-train_df['xmin'])/train_df['width']
# h
train_df['h'] = (train_df['ymax']-train_df['ymin'])/train_df['height']

# %%
train_df.head()
# Out:
#                                             filename  width  height   class  \
# 0  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 1  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 2  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 3  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 4  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
#
#    xmin  ymin  xmax  ymax  center_x  center_y         w         h
# 0   202   380   282   495  0.189062  0.607639  0.062500  0.159722
# 1   326   292   387   404  0.278516  0.483333  0.047656  0.155556
# 2   459   244   508   341  0.377734  0.406250  0.038281  0.134722
# 3   474   338   519   437  0.387891  0.538194  0.035156  0.137500
# 4   502   267   551   351  0.411328  0.429167  0.038281  0.116667

# %%
# center x, center y
test_df['center_x'] = ((test_df['xmax']+test_df['xmin'])/2)/test_df['width']
test_df['center_y'] = ((test_df['ymax']+test_df['ymin'])/2)/test_df['height']
# w
test_df['w'] = (test_df['xmax']-test_df['xmin'])/test_df['width']
# h
test_df['h'] = (test_df['ymax']-test_df['ymin'])/test_df['height']

# %%
test_df.head()
# Out:
#                                             filename  width  height   class  \
# 0  1-fps-2_00339_jpeg_jpg.rf.7a78aba0034a7c3daf39...    398     224  player
# 1  1-fps-2_00339_jpeg_jpg.rf.7a78aba0034a7c3daf39...    398     224  player
# 2  1-fps-2_00339_jpeg_jpg.rf.7a78aba0034a7c3daf39...    398     224  player
# 3  1-fps-2_00339_jpeg_jpg.rf.7a78aba0034a7c3daf39...    398     224  player
# 4  1-fps-2_00339_jpeg_jpg.rf.7a78aba0034a7c3daf39...    398     224  player
#
#    xmin  ymin  xmax  ymax  center_x  center_y         w         h
# 0   150   102   160   122  0.389447  0.500000  0.025126  0.089286
# 1   157    89   168   107  0.408291  0.437500  0.027638  0.080357
# 2   188    94   200   115  0.487437  0.466518  0.030151  0.093750
# 3   197    76   208   100  0.508794  0.392857  0.027638  0.107143
# 4   202   118   214   145  0.522613  0.587054  0.030151  0.120536

# %%
# label encoding
def label_encoding(x):
    labels = {'player':0}
    return labels[x]

# %%
train_df['id'] = train_df['class'].apply(label_encoding)
test_df['id'] = test_df['class'].apply(label_encoding)

# %%
train_df.head(10)
# Out:
#                                             filename  width  height   class  \
# 0  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 1  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 2  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 3  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 4  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 5  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 6  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 7  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 8  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
# 9  yt1s-com---Resume-Liverpool-01-Burnley-Premier...   1280     720  player
#
#    xmin  ymin  xmax  ymax  center_x  center_y         w         h  id
# 0   202   380   282   495  0.189062  0.607639  0.062500  0.159722   0
# 1   326   292   387   404  0.278516  0.483333  0.047656  0.155556   0
# 2   459   244   508   341  0.377734  0.406250  0.038281  0.134722   0
# 3   474   338   519   437  0.387891  0.538194  0.035156  0.137500   0
# 4   502   267   551   351  0.411328  0.429167  0.038281  0.116667   0
# 5   717   348   775   454  0.582812  0.556944  0.045312  0.147222   0
# 6   982   247  1043   351  0.791016  0.415278  0.047656  0.144444   0
# 7  1065   236  1115   360  0.851562  0.413889  0.039062  0.172222   0
# 8   685   217   740   321  0.556641  0.373611  0.042969  0.144444   0
# 9   666   185   714   290  0.539062  0.329861  0.037500  0.145833   0

# %%
parent_train_images='/kaggle/input/data-data/train'
parent_test_images='/kaggle/input/data-data/test'

# %%
parent_folder = '/kaggle/working/soccer-exercise-ball'
train_folder = '/kaggle/working/soccer-exercise-ball/trainFootball'
test_folder = '/kaggle/working/soccer-exercise-ball/testFootball'

os.mkdir(parent_folder)
os.mkdir(train_folder)
os.mkdir(test_folder)

# %%
cols = ['filename','id','center_x','center_y', 'w', 'h']
groupby_obj_train = train_df[cols].groupby('filename')
groupby_obj_test = test_df[cols].groupby('filename')

# %%
import shutil

# %%
#groupby_obj_train.get_group('000009.jpg').set_index('filename').to_csv('sample.txt',index=False,header=False)
# save each image in train/test folder and repective labels in .txt
def save_data(filename, src_folder_path, folder_path, group_obj):
    # move image
    src = os.path.join(src_folder_path,filename)
    dst = os.path.join(folder_path,filename)
    shutil.copy(src,dst) # move image to the destination folder

    # save the labels
    text_filename = os.path.join(folder_path,
                                 os.path.splitext(filename)[0]+'.txt')
    group_obj.get_group(filename).set_index('filename').to_csv(text_filename,sep=' ',index=False,header=False)

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())
filename_series_test = pd.Series(groupby_obj_test.groups.keys())

# %%
filename_series.apply(save_data,args=(parent_train_images,train_folder,groupby_obj_train))
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 109    None
# 110    None
# 111    None
# 112    None
# 113    None
# Length: 114, dtype: object

# %%
filename_series_test.apply(save_data,args=(parent_test_images,test_folder,groupby_obj_test))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# dtype: object

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15926, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 15926 (delta 20), reused 25 (delta 9), pack-reused 15880
# Receiving objects: 100% (15926/15926), 14.60 MiB | 22.14 MiB/s, done.
# Resolving deltas: 100% (10919/10919), done.

# %%
os.chdir('/kaggle/working/yolov5')

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.1.31)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (9.5.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (5.9.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.11.1)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.15.1)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (4.65.0)
# Collecting ultralytics>=8.0.147 (from -r requirements.txt (line 18))
#   Downloading ultralytics-8.0.163-py3-none-any.whl (610 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 610.8/610.8 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Collecting setuptools>=65.5.1 (from -r requirements.txt (line 42))
#   Downloading setuptools-68.1.2-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.1/805.1 kB 31.5 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.5.7)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.0.147->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Installing collected packages: setuptools, thop, ultralytics
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.8.0
#     Uninstalling setuptools-59.8.0:
#       Successfully uninstalled setuptools-59.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-api 1.18.0 requires importlib-metadata~=6.0.0, but you have importlib-metadata 6.7.0 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.1 which is incompatible.
# Successfully installed setuptools-68.1.2 thop-0.1.1.post2209072238 ultralytics-8.0.163

# %%
# !python /kaggle/working/yolov5/train.py --data /kaggle/input/player-yaml/dataset_player.yaml --cfg yolov5s.yaml --batch-size 34 --name Model --epochs 100
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=yolov5s.yaml, data=/kaggle/input/player-yaml/dataset_player.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=34, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=Model, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 14.5MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|███████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 119MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 342/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.00053125), 60 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://docs.ultralytics.com/yolov5/tutorials/multi_gpu_training to get started.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /kaggle/working/soccer-exercise-ball/trainFootball... 114 images
# train: New cache created: /kaggle/working/soccer-exercise-ball/trainFootball.cache
# val: Scanning /kaggle/working/soccer-exercise-ball/testFootball... 16 images, 0
# val: New cache created: /kaggle/working/soccer-exercise-ball/testFootball.cache
#
# AutoAnchor: 5.90 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/Model/labels.jpg...
# Image sizes 640 train, 640 val
# Using 1 dataloader workers
# Logging results to runs/train/Model
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99      3.86G     0.1312    0.08326          0        277        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173   0.000625     0.0173   0.000318   0.000106
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      3.86G     0.1267    0.08525          0        246        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173    0.00187      0.052    0.00103   0.000205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      3.86G     0.1182    0.09571          0        211        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173    0.00792       0.22    0.00734    0.00138
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      3.86G     0.1096     0.1014          0        268        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173     0.0737       0.15     0.0304    0.00563
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      3.86G     0.1035    0.08562          0        216        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.137      0.347      0.086     0.0176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      3.86G    0.09352    0.08212          0        219        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.193      0.399       0.14     0.0354
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      3.86G    0.09178    0.07654          0        300        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173     0.0695      0.434     0.0617     0.0157
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      3.86G    0.08086    0.07507          0        192        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173     0.0961      0.607     0.0894     0.0249
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      3.86G    0.07852     0.0745          0        172        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.191      0.422       0.23     0.0646
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      3.86G    0.07434    0.07882          0        265        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173     0.0953      0.775     0.0928     0.0312
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      3.86G    0.07154    0.07185          0        241        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.176      0.688      0.179     0.0745
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      3.86G    0.07093    0.06799          0        224        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.367      0.549       0.45      0.151
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      3.86G    0.06905    0.07908          0        266        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.173      0.734       0.18     0.0655
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/99      3.86G    0.06886    0.06938          0        209        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.347      0.549       0.46      0.148
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/99      3.86G    0.06571    0.06944          0        232        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.373      0.647      0.447      0.138
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/99      3.86G    0.06861    0.07126          0        237        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.133      0.861       0.13     0.0488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/99      3.86G    0.06719    0.07197          0        218        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.285      0.618      0.325     0.0964
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/99      3.86G     0.0697    0.06926          0        188        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.507      0.636      0.609      0.221
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/99      3.86G    0.06945    0.06766          0        228        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173       0.52      0.699       0.63      0.225
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/99      3.86G    0.06631    0.06932          0        154        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.338      0.676        0.4      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/99      3.86G    0.07206     0.0711          0        297        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.511      0.601      0.538      0.156
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/99      3.86G    0.06989     0.0668          0        214        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.623      0.705      0.727       0.25
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/99      3.86G    0.06482    0.06895          0        211        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.259      0.659      0.295      0.116
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/99      3.86G    0.06784     0.0678          0        297        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.404      0.642      0.487      0.118
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/99      3.86G    0.06605    0.06959          0        254        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.535      0.694       0.67      0.276
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/99      3.86G    0.06367    0.07191          0        241        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.491      0.653      0.562      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/99      3.86G    0.06049    0.06963          0        236        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.142      0.827      0.143     0.0561
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/99      3.86G    0.05909    0.06971          0        165        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.569      0.763      0.725      0.275
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/99      3.86G    0.05953    0.07161          0        243        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173       0.23      0.827      0.236     0.0936
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/99      3.86G    0.05885    0.06956          0        211        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.353      0.618      0.527      0.213
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/99      3.86G    0.05506    0.07306          0        264        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.496       0.74       0.67      0.279
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/99      3.86G    0.05634    0.06865          0        231        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.456      0.642      0.571      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/99      3.86G    0.05412    0.06874          0        296        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.606      0.792      0.746      0.344
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/99      3.86G    0.05354     0.0664          0        214        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.575      0.821       0.74      0.352
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/99      3.86G    0.05093    0.06379          0        244        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173       0.56      0.832      0.718      0.294
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/99      3.86G    0.05089    0.06464          0        217        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.521      0.803      0.668      0.284
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/99      3.86G    0.04866    0.06604          0        264        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.433      0.832        0.6       0.28
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/99      3.86G    0.04868    0.06362          0        256        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.496      0.827      0.671      0.308
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/99      3.86G    0.05109    0.06278          0        214        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.591      0.838      0.794       0.39
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/99      3.86G    0.04803     0.0606          0        217        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.621      0.855      0.791      0.342
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/99      3.86G    0.04637    0.06092          0        209        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.664      0.879      0.871      0.428
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/99      3.86G    0.04766      0.064          0        216        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.745       0.88      0.902      0.426
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/99      3.86G    0.04696     0.0612          0        239        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.662      0.867      0.852      0.415
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/99      3.86G    0.04461    0.05983          0        227        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.645      0.879      0.814      0.363
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/99      3.86G    0.04498    0.06514          0        280        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.722      0.899      0.896      0.421
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/99      3.86G    0.04331     0.0616          0        193        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.725      0.901      0.907      0.442
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/99      3.86G    0.04348    0.06095          0        193        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.733      0.887      0.885      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/99      3.86G    0.04119      0.058          0        238        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.661      0.879      0.853      0.423
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/99      3.86G    0.04154    0.06346          0        279        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.758      0.873      0.917      0.477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/99      3.86G    0.04129    0.06441          0        280        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.848      0.901      0.939      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/99      3.86G    0.04123    0.05749          0        195        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.833      0.896      0.951      0.487
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/99      3.86G    0.03928    0.06097          0        302        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.828      0.884      0.937      0.461
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/99      3.86G    0.03938     0.0636          0        297        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.828      0.884      0.955      0.457
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/99      3.86G    0.03875    0.06384          0        320        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.884      0.936       0.97      0.492
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/99      3.86G    0.03864    0.05978          0        264        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.898       0.97       0.97      0.483
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/99      3.86G    0.04022    0.05937          0        173        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.904      0.942      0.972      0.521
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/99      3.86G    0.03921    0.05314          0        168        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.968      0.948      0.977      0.537
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/99      3.86G    0.03907    0.05803          0        163        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.969       0.96       0.98      0.548
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/99      3.86G    0.03733     0.0567          0        250        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.974      0.954      0.976      0.548
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/99      3.86G    0.03813     0.0607          0        236        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.982      0.957      0.982      0.555
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       60/99      3.86G    0.03652    0.05998          0        233        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988      0.959      0.982      0.531
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       61/99      3.86G    0.03667    0.05919          0        253        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.982       0.96      0.987      0.544
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       62/99      3.86G    0.03636    0.05791          0        241        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988       0.96      0.986      0.558
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       63/99      3.86G    0.03582    0.05725          0        204        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.984      0.942      0.986      0.539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       64/99      3.86G    0.03521    0.05947          0        244        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.981      0.965      0.988      0.538
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       65/99      3.86G    0.03502    0.05569          0        268        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.971      0.954      0.989      0.549
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       66/99      3.86G    0.03596    0.05737          0        215        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.976       0.95      0.989      0.545
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       67/99      3.86G    0.03394    0.05401          0        169        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988      0.963       0.99      0.554
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       68/99      3.86G    0.03429    0.05534          0        186        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.977      0.974      0.992      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       69/99      3.86G    0.03343    0.05736          0        212        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.981      0.971      0.991      0.571
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       70/99      3.86G    0.03482    0.05783          0        247        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988       0.97      0.992      0.548
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       71/99      3.86G    0.03355    0.05718          0        274        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.977      0.971      0.991      0.533
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       72/99      3.86G    0.03254    0.05854          0        246        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.977      0.965      0.991      0.561
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       73/99      3.86G    0.03398    0.05984          0        229        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.985      0.971      0.992      0.593
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       74/99      3.86G    0.03374    0.05639          0        221        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.993      0.971      0.992      0.566
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       75/99      3.86G    0.03205    0.05534          0        185        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.986      0.971      0.992      0.581
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       76/99      3.86G    0.03252    0.05592          0        266        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.986      0.971      0.991      0.584
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       77/99      3.86G    0.03221    0.05583          0        270        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.983      0.965      0.991      0.595
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       78/99      3.86G    0.03332    0.05768          0        227        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.974       0.96      0.984      0.552
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       79/99      3.86G    0.03157    0.05212          0        200        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.986      0.965      0.992       0.61
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       80/99      3.86G    0.03158    0.05727          0        249        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988      0.965      0.992      0.587
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       81/99      3.86G    0.03074    0.05596          0        232        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.977      0.954      0.991      0.603
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       82/99      3.86G    0.03187    0.05264          0        203        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.985      0.954      0.992      0.591
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       83/99      3.86G    0.03045    0.05531          0        180        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.964      0.977      0.992       0.59
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       84/99      3.86G    0.03104     0.0553          0        237        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988      0.956      0.992      0.629
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       85/99      3.86G    0.02927    0.05128          0        221        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988      0.959      0.992      0.615
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       86/99      3.86G    0.02924    0.05349          0        228        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988      0.965      0.992      0.611
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       87/99      3.86G    0.02938    0.05327          0        208        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.986       0.96      0.992      0.616
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       88/99      3.86G    0.02931      0.054          0        259        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.987       0.96      0.992      0.596
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       89/99      3.86G    0.02994    0.05299          0        195        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.988      0.964      0.993      0.615
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       90/99      3.86G    0.02935    0.05193          0        226        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.982      0.948      0.991      0.601
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       91/99      3.86G    0.02973    0.05421          0        211        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.982      0.957      0.992      0.626
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       92/99      3.86G    0.03042    0.05657          0        202        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.985       0.96      0.993      0.626
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       93/99      3.86G    0.02928    0.05327          0        179        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.987       0.96      0.993      0.623
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       94/99      3.86G    0.02807     0.0517          0        204        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.986       0.96      0.993      0.625
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       95/99      3.86G    0.02899    0.05611          0        280        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.982      0.969      0.993      0.631
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       96/99      3.86G    0.02879    0.05045          0        182        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.984       0.96      0.993      0.624
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       97/99      3.86G    0.02925     0.0566          0        317        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.983       0.96      0.993      0.618
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       98/99      3.86G    0.02875    0.05656          0        262        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.986       0.96      0.993      0.628
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       99/99      3.86G    0.02761     0.0536          0        290        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.975       0.96      0.991      0.627
#
# 100 epochs completed in 0.147 hours.
# Optimizer stripped from runs/train/Model/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/Model/weights/best.pt, 14.3MB
#
# Validating runs/train/Model/weights/best.pt...
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         16        173      0.985       0.96      0.993       0.63
# Results saved to runs/train/Model

# %% [markdown]
# # For Exporting the Trained Model

# %%
# !python /kaggle/working/yolov5/export.py --weights /kaggle/working/yolov5/runs/train/Model/weights/best.pt --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['/kaggle/working/yolov5/runs/train/Model/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /kaggle/working/yolov5/runs/train/Model/weights/best.pt with output shape (1, 25200, 6) (13.7 MB)
#
# TorchScript: starting export with torch 2.0.0...
# TorchScript: export success ✅ 3.3s, saved as /kaggle/working/yolov5/runs/train/Model/weights/best.torchscript (27.2 MB)
#
# ONNX: starting export with onnx 1.14.0...
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: export success ✅ 1.4s, saved as /kaggle/working/yolov5/runs/train/Model/weights/best.onnx (27.2 MB)
#
# Export complete (5.5s)
# Results saved to /kaggle/working/yolov5/runs/train/Model/weights
# Detect:          python detect.py --weights /kaggle/working/yolov5/runs/train/Model/weights/best.onnx
# Validate:        python val.py --weights /kaggle/working/yolov5/runs/train/Model/weights/best.onnx
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', '/kaggle/working/yolov5/runs/train/Model/weights/best.onnx')
# Visualize:       https://netron.app

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))

# %%
download_file('/kaggle/working/yolov5/runs/train/Model', 'Model')
# Out:
# /kaggle/working/Model.zip

# %%
# !pip install PyYAML

# %%
import cv2
import numpy as np
import os
import yaml
from yaml.loader import SafeLoader

# %%
# load YAML
with open('/kaggle/input/player-yaml/dataset_player.yaml',mode='r') as f:
    data_yaml = yaml.load(f,Loader=SafeLoader)
    
labels = data_yaml['names']
print(labels)
# Out:
# ['player']

# %%
# load YOLO model
yolo = cv2.dnn.readNetFromONNX('/kaggle/working/yolov5/runs/train/Model/weights/best.onnx')
yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

# %%
# load the image
img = cv2.imread('/kaggle/input/ball-predict/soccer_image01.png')
image = img.copy()
row, col, d = image.shape


# get the YOLO prediction from the the image
# step-1 convert image into square image (array)
max_rc = max(row,col)
input_image = np.zeros((max_rc,max_rc,3),dtype=np.uint8)
input_image[0:row,0:col] = image
# step-2: get prediction from square array
INPUT_WH_YOLO = 640
blob = cv2.dnn.blobFromImage(input_image,1/255,(INPUT_WH_YOLO,INPUT_WH_YOLO),swapRB=True,crop=False)
yolo.setInput(blob)
preds = yolo.forward() # detection or prediction from YOLO

# %%
print(preds.shape)
# Out:
# (1, 25200, 6)

# %%
# Non Maximum Supression
# step-1: filter detection based on confidence (0.4) and probability score (0.25)
detections = preds[0]
boxes = []
confidences = []
classes = []

# widht and height of the image (input_image)
image_w, image_h = input_image.shape[:2]
x_factor = image_w/INPUT_WH_YOLO
y_factor = image_h/INPUT_WH_YOLO

for i in range(len(detections)):
    row = detections[i]
    confidence = row[4] # confidence of detection an object
    if confidence > 0.4:
        class_score = row[5:].max() # maximum probability from 20 objects
        class_id = row[5:].argmax() # get the index position at which max probabilty occur
        
        if class_score > 0.25:
            cx, cy, w, h = row[0:4]
            # construct bounding from four values
            # left, top, width and height
            left = int((cx - 0.5*w)*x_factor)
            top = int((cy - 0.5*h)*y_factor)
            width = int(w*x_factor)
            height = int(h*y_factor)
            
            box = np.array([left,top,width,height])
            
            # append values into the list
            confidences.append(confidence)
            boxes.append(box)
            classes.append(class_id)
            
# clean
boxes_np = np.array(boxes).tolist()
confidences_np = np.array(confidences).tolist()

# NMS
index = cv2.dnn.NMSBoxes(boxes_np,confidences_np,0.25,0.45).flatten()

# %%
index
# Out:
# array([ 36, 219,  16, 215,  13,   8,  61, 157, 139, 211,   2, 136, 196],
#       dtype=int32)

# %%
# Draw the Bounding
for ind in index:
    # extract bounding box
    x,y,w,h = boxes_np[ind]
    bb_conf = int(confidences_np[ind]*100)
    classes_id = classes[ind]
    class_name = labels[classes_id]
    
    text = f'{class_name}: {bb_conf}%'
    
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
    cv2.rectangle(image,(x,y-30),(x+w,y),(255,255,255),-1)
    
    cv2.putText(image,text,(x,y-10),cv2.FONT_HERSHEY_PLAIN,0.7,(0,0,0),1)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.imshow(img, cmap='gray')
# plt.colorbar();

# %%
plt.imshow(image, cmap='gray')
# plt.colorbar();
